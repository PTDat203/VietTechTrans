# %% [markdown]
# # Phase 06B.2 — OPUS-MT pretrained baseline VI→EN
#
# Notebook này ghi nhận baseline Vietnamese → English của OPUS-MT trước khi áp dụng miền CNTT. Nó dùng General Test và IT Test đã sealed ở Phase 05, cùng protocol v2 với chiều EN→VI; không fine-tune, không sửa dữ liệu test và không gộp hai test set.

# %%
from pathlib import Path
import json
import subprocess
import sys

import pandas as pd
from IPython.display import Markdown, display

ROOT = Path.cwd().resolve()
if not (ROOT / 'configs').is_dir():
    ROOT = ROOT.parents[1]
sys.path.insert(0, str(ROOT / 'src'))

from core_mt.adapters.opus_mt import OpusMTAdapter
from core_mt.contracts import Direction
from core_mt.data import load_locked_evaluation_set
from core_mt.protocol import load_frozen_protocol

CONFIG_PATH = ROOT / 'configs' / 'opus_mt_baseline_v1.json'
PROTOCOL_PATH = ROOT / 'configs' / 'evaluation_protocol_v2.json'
RUN_ROOT = ROOT / 'runs' / 'core_mt_baseline_v2' / 'opus_mt'
config = json.loads(CONFIG_PATH.read_text(encoding='utf-8'))
protocol = load_frozen_protocol(PROTOCOL_PATH)
print(f'Protocol: {protocol.protocol_version}; dataset release: {protocol.dataset_release}')
# Out:
# Protocol: core_mt_baseline_v2; dataset release: phase05_release_v1

# %% [markdown]
# ## 1. Phần riêng của OPUS-MT VI→EN
#
# Shared CORE quyết định dataset, seed, beam size, metric và artifact. Khi `direction = 'vi_to_en'`, adapter tự chọn checkpoint `Helsinki-NLP/opus-mt-vi-en`. Checkpoint này không yêu cầu target-language prefix, nên câu tiếng Việt được gửi nguyên vẹn vào tokenizer.

# %%
import core_mt.adapters.opus_mt as opus_module
display(Markdown(opus_module.__doc__.strip()))
display(Markdown(OpusMTAdapter.__doc__.strip()))
# Out:
# Adapter OPUS-MT: phần riêng duy nhất của nhánh Marian bilingual.
#
# Shared layer đã quyết định dataset, direction, seed và generation settings.
# Adapter này chỉ làm ba việc OPUS-specific: chọn checkpoint theo direction, thêm
# target-language token khi model card yêu cầu, và gọi tokenizer/model Marian.
# Không có rule nào phụ thuộc General Test hoặc IT Test trong file này.
# Bọc hai checkpoint OPUS-MT thành cùng interface `TranslationAdapter`.
#
# EN→VI và VI→EN là hai checkpoint khác nhau. Điều này khác model multilingual:
# checkpoint được chọn trước khi inference, không phải bằng cách nhìn kết quả
# test rồi chọn model tốt hơn.

# %%
pd.DataFrame([
    {
        'direction': direction,
        'checkpoint': spec['model_id'],
        'requested_revision': spec['revision'],
        'mandatory_prefix': spec['source_prefix'] or '(none)',
    }
    for direction, spec in config['directions'].items()
])
# Out:
#   direction                  checkpoint requested_revision mandatory_prefix
# 0  en_to_vi  Helsinki-NLP/opus-mt-en-vi               main          >>vie<<
# 1  vi_to_en  Helsinki-NLP/opus-mt-vi-en               main           (none)

# %% [markdown]
# ## 2. Kiểm tra input VI→EN trước tokenizer
#
# Đây là kiểm tra format, chưa tải checkpoint. Với chiều VI→EN, adapter không thêm `>>vie<<` hoặc token nào khác. Câu nguồn được giữ nguyên; điều này bảo đảm rule prefix của EN→VI không vô tình áp dụng sang chiều ngược lại.

# %%
source_vi = 'Cài đặt gói từ kho lưu trữ.'
adapter_preview = OpusMTAdapter(Direction.VI_TO_EN, CONFIG_PATH, 'cpu')
prepared = adapter_preview.prepare_input(source_vi)
assert prepared == source_vi
pd.DataFrame([{
    'direction': Direction.VI_TO_EN.value,
    'checkpoint': config['directions']['vi_to_en']['model_id'],
    'source': source_vi,
    'input_to_tokenizer': prepared,
    'prefix_added': False,
}])
# Out:
#   direction                  checkpoint                       source  \
# 0  vi_to_en  Helsinki-NLP/opus-mt-vi-en  Cài đặt gói từ kho lưu trữ.
#
#             input_to_tokenizer  prefix_added
# 0  Cài đặt gói từ kho lưu trữ.         False

# %% [markdown]
# ## 3. Protocol benchmark v2
#
# Chất lượng và hiệu năng là hai phép đo khác nhau. Mỗi câu của General Test và IT Test được sinh bản dịch đúng một lần để tính chrF++ và SacreBLEU. Sau đó, mỗi test set chọn tối đa 128 câu bằng SHA-256 của `seed:row_id`, warm-up tối đa 32 câu, rồi đo 5 lượt trên mẫu cố định. Vì vậy benchmark giữ được tính lặp lại nhưng không dịch lặp toàn bộ corpus năm lần.

# %%
datasets = {name: load_locked_evaluation_set(name, ROOT) for name in protocol.evaluation_sets}
workload = pd.DataFrame([
    {
        'test_set': name,
        'quality_sentences': len(dataset.rows),
        'quality_passes': protocol.benchmark.quality_passes,
        'latency_sample_max': min(len(dataset.rows), protocol.benchmark.latency_sample_size),
        'warmup_max': min(len(dataset.rows), protocol.benchmark.warmup_sentences),
        'latency_repeats': protocol.benchmark.latency_repeats,
    }
    for name, dataset in datasets.items()
])
workload
# Out:
#        test_set  quality_sentences  quality_passes  latency_sample_max  \
# 0  general_test               1012               1                 128
# 1       it_test              13851               1                 128
#
#    warmup_max  latency_repeats
# 0          32                5
# 1          32                5

# %% [markdown]
# ## 4. Lệnh chạy baseline
#
# Cell dưới được đặt `False` để mở notebook không tự khởi chạy nhiều giờ. Khi đã sẵn sàng chạy từ notebook, đổi biến thành `True`. Runner luôn gọi lại Phase 05 gate trước khi tải model. Trong lúc chạy, thư mục `.in_progress` có log; chỉ sau khi đủ sáu artifact, runner mới đổi tên thành thư mục kết quả chính thức.

# %%
direction = 'vi_to_en'
final_dir = RUN_ROOT / direction
active_dir = RUN_ROOT / f'{direction}.in_progress'
RUN_FULL_BASELINE = False
if active_dir.is_dir():
    print('Đã có run dở dang. Đọc cell trạng thái/log; không khởi chạy chồng lên run này.')
elif final_dir.is_dir():
    print('Baseline VI→EN đã hoàn thành. Đọc cell kết quả phía dưới.')
elif RUN_FULL_BASELINE:
    command = [
        sys.executable, 'tools/run_opus_mt_baseline.py',
        '--direction', 'vi_to_en', '--device', 'cpu',
        '--progress-interval', '250', '--preview', '2',
    ]
    # Kernel Windows mặc định đọc pipe bằng CP1252; model có thể in UTF-8.
    # Tự giải mã UTF-8 để log tiếng Việt không làm reader thread lỗi.
    result = subprocess.run(
        command, cwd=ROOT, text=True, capture_output=True,
        encoding='utf-8', errors='replace',
    )
    print(result.stdout)
    if result.stderr:
        print(result.stderr)
    print(f'Exit code: {result.returncode}')
else:
    print('Đặt RUN_FULL_BASELINE = False chỉ khi chưa có run dở dang hoặc completed run.')
# Out:
# PHASE_05_GATE=PASS
# Starting model=opus_mt; direction=vi_to_en; device=cpu
# Resolved checkpoint=Helsinki-NLP/opus-mt-vi-en; revision=c8d2853e77f5fae31124d993e0b35176b1c8914e
# [general_test] quality pass 1/1: 1012 released sentences
# [general_test] quality preview 1: source='“Chúng tôi hiện có đàn chuột 4 tháng tuổi đã hết bị tiểu đường,” ông nói thêm.'
# [general_test] quality preview 1: prediction='“ We now have four - month - old rats who are no longer diabetes, ” he added.'
# [general_test] quality preview 2: source='Tiến sĩ Ehud Ur, giáo sư y khoa của Trường Đại học Dalhousie ở Halifax, Nova Scotia và là chủ tịch ban lâm sàng và khoa học của Hiệp hội Bệnh Tiểu đường Canada cảnh báo rằng nghiên'
# [general_test] quality preview 2: prediction='Dr. Ehud Ur, professor of medicine at Dalhousie University at Albrecht, Nova Schiller, and president of the clinical and scientific department of the Canadian Amity Association, wa'
# [general_test] quality: 250/1012 sentences
# [general_test] quality: 500/1012 sentences
# [general_test] quality: 750/1012 sentences
# [general_test] quality: 1000/1012 sentences
# [general_test] quality: 1012/1012 sentences
# [general_test] latency probe: 128 deterministic sentences × 5 repeats
# [general_test] repeat 1/5 started
# [general_test] repeat 1: 128/128 probe sentences
# [general_test] repeat 2/5 started
# [general_test] repeat 2: 128/128 probe sentences
# [general_test] repeat 3/5 started
# [general_test] repeat 3: 128/128 probe sentences
# [general_test] repeat 4/5 started
# [general_test] repeat 4: 128/128 probe sentences
# [general_test] repeat 5/5 started
# [general_test] repeat 5: 128/128 probe sentences
# [general_test] chrF++=50.8015; SacreBLEU=21.2546
# [it_test] quality pass 1/1: 13851 released sentences
# [it_test] quality preview 1: source='Samsung Galaxy Buds2 Pro Twin Bao Edition ra mắt'
# [it_test] quality preview 1: prediction='KENYPAL Buds2 Pro Twins Edition Releases'
# [it_test] quality preview 2: source='Falcons vs. Lions Phát trực tiếp: Cách xem trực tuyến NFL Tuần 3 hôm nay - CNET'
# [it_test] quality preview 2: prediction='Falcons v. Lions live:'
# [it_test] quality: 250/13851 sentences
# [it_test] quality: 500/13851 sentences
# [it_test] quality: 750/13851 sentences
# [it_test] quality: 1000/13851 sentences
# [it_test] quality: 1250/13851 sentences
# [it_test] quality: 1500/13851 sentences
# [it_test] quality: 1750/13851 sentences
# [it_test] quality: 2000/13851 sentences
# [it_test] quality: 2250/13851 sentences
# [it_test] quality: 2500/13851 sentences
# [it_test] quality: 2750/13851 sentences
# [it_test] quality: 3000/13851 sentences
# [it_test] quality: 3250/13851 sentences
# [it_test] quality: 3500/13851 sentences
# [it_test] quality: 3750/13851 sentences
# [it_test] quality: 4000/13851 sentences
# [it_test] quality: 4250/13851 sentences
# [it_test] quality: 4500/13851 sentences
# [it_test] quality: 4750/13851 sentences
# [it_test] quality: 5000/13851 sentences
# [it_test] quality: 5250/13851 sentences
# [it_test] quality: 5500/13851 sentences
# [it_test] quality: 5750/13851 sentences
# [it_test] quality: 6000/13851 sentences
# [it_test] quality: 6250/13851 sentences
# [it_test] quality: 6500/13851 sentences
# [it_test] quality: 6750/13851 sentences
# [it_test] quality: 7000/13851 sentences
# [it_test] quality: 7250/13851 sentences
# [it_test] quality: 7500/13851 sentences
# [it_test] quality: 7750/13851 sentences
# [it_test] quality: 8000/13851 sentences
# [it_test] quality: 8250/13851 sentences
# [it_test] quality: 8500/13851 sentences
# [it_test] quality: 8750/13851 sentences
# [it_test] quality: 9000/13851 sentences
# [it_test] quality: 9250/13851 sentences
# [it_test] quality: 9500/13851 sentences
# [it_test] quality: 9750/13851 sentences
# [it_test] quality: 10000/13851 sentences
# [it_test] quality: 10250/13851 sentences
# [it_test] quality: 10500/13851 sentences
# [it_test] quality: 10750/13851 sentences
# [it_test] quality: 11000/13851 sentences
# [it_test] quality: 11250/13851 sentences
# [it_test] quality: 11500/13851 sentences
# [it_test] quality: 11750/13851 sentences
# [it_test] quality: 12000/13851 sentences
# [it_test] quality: 12250/13851 sentences
# [it_test] quality: 12500/13851 sentences
# [it_test] quality: 12750/13851 sentences
# [it_test] quality: 13000/13851 sentences
# [it_test] quality: 13250/13851 sentences
# [it_test] quality: 13500/13851 sentences
# [it_test] quality: 13750/13851 sentences
# [it_test] quality: 13851/13851 sentences
# [it_test] latency probe: 128 deterministic sentences × 5 repeats
# [it_test] repeat 1/5 started
# [it_test] repeat 1: 128/128 probe sentences
# [it_test] repeat 2/5 started
# [it_test] repeat 2: 128/128 probe sentences
# [it_test] repeat 3/5 started
# [it_test] repeat 3: 128/128 probe sentences
# [it_test] repeat 4/5 started
# [it_test] repeat 4: 128/128 probe sentences
# [it_test] repeat 5/5 started
# [it_test] repeat 5: 128/128 probe sentences
# [it_test] chrF++=49.2499; SacreBLEU=20.5334
# Baseline completed successfully.
#
#
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]C:\Users\ADMIN\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ADMIN\.cache\huggingface\hub\models--Helsinki-NLP--opus-mt-vi-en. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
#
# Fetching 8 files:  12%|█▎        | 1/8 [00:00<00:02,  2.51it/s]
# Fetching 8 files:  50%|█████     | 4/8 [00:17<00:18,  4.65s/it]
# Fetching 8 files: 100%|██████████| 8/8 [00:17<00:00,  2.16s/it]
# C:\Users\ADMIN\anaconda3\Lib\site-packages\transformers\models\marian\tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
#
# Exit code: 0

# %% [markdown]
# ## 5. Theo dõi trạng thái và log
#
# Cell này chỉ đọc file. Nó hoạt động cả trước khi chạy, khi đang chạy và sau khi hoàn thành.

# %%
direction = 'vi_to_en'
final_dir = RUN_ROOT / direction
active_dir = RUN_ROOT / f'{direction}.in_progress'
run_dir = final_dir if final_dir.is_dir() else active_dir

if not run_dir.is_dir():
    print('Chưa có run OPUS-MT VI→EN v2.')
else:
    state = 'COMPLETED' if run_dir == final_dir else 'IN PROGRESS — chưa phải kết quả cuối'
    print(f'State: {state}')
    print('Artifacts:', sorted(path.name for path in run_dir.iterdir()))
    log = run_dir / 'run.log'
    if log.is_file():
        print('\n'.join(log.read_text(encoding='utf-8').splitlines()[-20:]))
# Out:
# State: COMPLETED
# Artifacts: ['benchmark.json', 'environment.txt', 'metrics.json', 'predictions.jsonl', 'resolved_config.json', 'run.log']
# [it_test] quality: 12500/13851 sentences
# [it_test] quality: 12750/13851 sentences
# [it_test] quality: 13000/13851 sentences
# [it_test] quality: 13250/13851 sentences
# [it_test] quality: 13500/13851 sentences
# [it_test] quality: 13750/13851 sentences
# [it_test] quality: 13851/13851 sentences
# [it_test] latency probe: 128 deterministic sentences × 5 repeats
# [it_test] repeat 1/5 started
# [it_test] repeat 1: 128/128 probe sentences
# [it_test] repeat 2/5 started
# [it_test] repeat 2: 128/128 probe sentences
# [it_test] repeat 3/5 started
# [it_test] repeat 3: 128/128 probe sentences
# [it_test] repeat 4/5 started
# [it_test] repeat 4: 128/128 probe sentences
# [it_test] repeat 5/5 started
# [it_test] repeat 5: 128/128 probe sentences
# [it_test] chrF++=49.2499; SacreBLEU=20.5334
# Baseline completed successfully.

# %% [markdown]
# ## 6. Đọc prediction, metric và benchmark sau khi hoàn thành
#
# Không có số liệu giả trong notebook. Nếu run chưa hoàn thành, cell sẽ báo trạng thái thay vì tự tạo chrF++, SacreBLEU, RAM hoặc latency.

# %%
if not final_dir.is_dir():
    print('Metrics chưa có: chờ run VI→EN hoàn thành và được commit thành thư mục kết quả.')
else:
    metrics = json.loads((final_dir / 'metrics.json').read_text(encoding='utf-8'))['by_test_set']
    benchmark = json.loads((final_dir / 'benchmark.json').read_text(encoding='utf-8'))['by_test_set']
    predictions = [json.loads(line) for line in (final_dir / 'predictions.jsonl').read_text(encoding='utf-8').splitlines()]
    display(pd.DataFrame(predictions)[['test_set', 'row_id', 'source', 'reference', 'prediction']].head(8))
    display(pd.DataFrame(metrics).T.rename_axis('test_set'))
    display(pd.DataFrame(benchmark).T.rename_axis('test_set'))
# Out:
#        test_set row_id                                             source  \
# 0  general_test      0  “Chúng tôi hiện có đàn chuột 4 tháng tuổi đã h...
# 1  general_test      1  Tiến sĩ Ehud Ur, giáo sư y khoa của Trường Đại...
# 2  general_test      2  Giống như một số chuyên gia khác, ông ấy hoài ...
# 3  general_test      3  Vào ngày thứ Hai, Sara Danius, thư ký thường t...
# 4  general_test      4  Danius đã nói, “Ngay lúc này chúng ta chẳng là...
# 5  general_test      5  Trước đây, giám đốc điều hành của Ring, Jamie ...
# 6  general_test      6      Ông đã lắp môt chuông cửa WiFi, ông cho biết.
# 7  general_test      7  Siminoff cho biết doanh số tăng sau sự xuất hi...
#
#                                            reference  \
# 0  "We now have 4-month-old mice that are non-dia...
# 1  Dr. Ehud Ur, professor of medicine at Dalhousi...
# 2  Like some other experts, he is skeptical about...
# 3  On Monday, Sara Danius, permanent secretary of...
# 4  Danius said, "Right now we are doing nothing. ...
# 5  Previously, Ring's CEO, Jamie Siminoff, remark...
# 6                He built a WiFi door bell, he said.
# 7  Siminoff said sales boosted after his 2013 app...
#
#                                           prediction
# 0  “ We now have four - month - old rats who are ...
# 1  Dr. Ehud Ur, professor of medicine at Dalhousi...
# 2  Like some other specialists, he was skeptical ...
# 3  On the second day, Sara Danius, a regular secr...
# 4  Danius said, “We have done nothing right now; ...
# 5  Previously, the CEO of the Ring, Jamie Siminof...
# 6             He put up a bell to the door, he said.
# 7  Siminoff said the sales increased after his ar...
#                  chrF++  sacreBLEU sacrebleu_version
# test_set
# general_test  50.801525  21.254576             2.6.0
# it_test       49.249921   20.53341             2.6.0
#              quality_sentences quality_passes latency_sample_size  \
# test_set
# general_test              1012              1                 128
# it_test                  13851              1                 128
#
#              latency_sample_seed warmup_sentences latency_repeats  \
# test_set
# general_test                  42               32               5
# it_test                       42               32               5
#
#                            latency_unit peak_process_rss_bytes  \
# test_set
# general_test  milliseconds per sentence              893333504
# it_test       milliseconds per sentence              969687040
#
#              latency_median_ms latency_p95_ms
# test_set
# general_test          508.1213       805.9924
# it_test               292.8434       553.8472

# %% [markdown]
# ## 7. Biểu đồ General Test và IT Test
#
# Hai cột được giữ riêng. Chỉ khi cả hai có metric hoàn chỉnh thì biểu đồ mới xuất hiện; không tính trung bình giữa hai miền.

# %%
if final_dir.is_dir():
    metric_table = pd.DataFrame(metrics).T[['chrF++', 'sacreBLEU']]
    ax = metric_table.plot.bar(rot=0, figsize=(8, 4), title='OPUS-MT VI→EN: General Test và IT Test')
    ax.set_xlabel('Test set')
    ax.set_ylabel('Score')
else:
    print('Biểu đồ sẽ xuất hiện sau khi metrics.json được tạo.')

# %% [markdown]
# ## 8. Unit test không tải checkpoint
#
# Các test kiểm tra adapter, protocol v2 và contract artifact. Chúng không thay thế inference thật; kết quả baseline chỉ hợp lệ khi runner hoàn thành toàn bộ artifact.

# %%
for pattern in ['test_core_shared.py', 'test_opus_mt_adapter.py', 'test_runner_contract.py']:
    result = subprocess.run(
        [sys.executable, '-m', 'unittest', 'discover', '-s', 'tests', '-p', pattern],
        cwd=ROOT, text=True, capture_output=True,
    )
    print(result.stdout + result.stderr)
    assert result.returncode == 0, pattern
# Out:
# ...
# ----------------------------------------------------------------------
# Ran 3 tests in 0.011s
#
# OK
#
# ...
# ----------------------------------------------------------------------
# Ran 3 tests in 0.001s
#
# OK
#
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.062s
#
# OK
